# %%
import quandl
import requests
import pandas as pd
import os, time



#https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?ticker=AAPL&api_key=VNBM61bWK3XD1xqdxNiC

#print dir(quandl)

API_KEY = "VNBM61bWK3XD1xqdxNiC"

def findTickers(outputfolder):
    tickers = []
    for root, dirs, files in os.walk(outputfolder):
        path = root.split('/')
        #print (len(path) - 1) *'---' , os.path.basename(root)
        for file in files:
            
            

            filename = os.path.join(root, file)
            print (filename)
            #print root, dirs, path, file
            #print filename.split("_"), filename

            if ".txt" in file:
                tickers.append(file.split("_")[0])
    return tickers


def getData(url, ticker, folder, type_data):
    print ("Trying (EPS/PE)... ", ticker, folder)
    r = requests.get(url, stream=True)
    virtual_file = ""
    for chunk in r.iter_content(chunk_size=1024): 
        if chunk: # filter out keep-alive new chunks
            #virtual_file += chunk + "\n"
            virtual_file += chunk
    #result = virtual_file.replace('"', '').strip('\r\n')
    result = virtual_file
    with open(os.path.join(folder, ticker + "_"+type_data+".txt"), "w") as writer:
        writer.write(result)
    return result
    
    


if __name__ == '__main__':
    
    print(1)
    tickers = findTickers(".")
    
    try:
        with open('current_tickers.txt', 'r') as file:
            current_tick = file.read()
            print(2)
    except IOError:
        current_tick = None
        print ("IOERROR")
        print(3)
        pass
    
    
    start = False
    print (tickers)
    for i, ticker in enumerate(tickers):
        print ("Ticker: ", ticker)
        if ticker == current_tick or start or current_tick == None:
            start = True
            url = "https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?ticker="+ticker+"&api_key="+API_KEY
            getData(url, ticker, "pe", "FULL")
            url = "https://www.quandl.com/api/v3/datasets/ZFA/"+ticker+"_EPS_BASIC_CONSOL_Q.csv?api_key="+API_KEY
            getData(url, ticker, "eps", "EPS")
            with open('current_tickers.txt', 'w') as file:
                file.write(ticker)

            if i % 100 == 0:
                print ("Pausing...")
                time.sleep(5)
        #url = "https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?ticker="+ticker+"&api_key="+API_KEY
        #url = "https://www.quandl.com/api/v3/datasets/ZFA/GE_EPS_BASIC_CONT_OPER_Q.csv?api_key="+API_KEY
        #url = "https://www.quandl.com/api/v3/datasets/ZFA/"+ticker+"_EPS_BASIC_CONSOL_Q.csv?api_key="+API_KEY
        #url = "https://www.quandl.com/api/v3/datatables/ZACKS/FR.csv?api_key="+API_KEY"

        #r = requests.get(url, stream=True)
        #virtual_file = ""
        #for chunk in r.iter_content(chunk_size=1024): 
        #if chunk: # filter out keep-alive new chunks
                #virtual_file += chunk + "\n"
        #virtual_file += chunk
        #result = virtual_file.replace('"', '').strip('\r\n')
        #result = virtual_file
        #with open(os.path.join("eps", ticker + "_EPS.txt"), "w") as writer:
        #writer.write(result)


    #print result[0]
    #res = pd.read_csv(os.path.join("eps", ticker + "_EPS.txt"))
    #print res.columns.values
    #print res.head()
    #res.calendardate = pd.to_datetime(res.calendardate, format="%Y-%m-%d", errors="coerce")
    #quart = res.set_index(['calendardate'])
    #monthly = quart.pe.resample("M", how="mean").dropna()
    #print monthly.head()
    #print monthly
# Out:
# 1
# .\current_tickers.txt
# .\News Scrapper.ipynb
# .\pe ratios.ipynb
# .\pe1.ipynb
# .\Stock Price Extraction API - Yahoo Based.ipynb
# .\StockPricePredictionUsingTextMining.xlsx
# .\tickers.txt
# .\Twitter Based Sentimental Analysis - Stocks.ipynb
# .\WIT-summary.json
# .\.ipynb_checkpoints\pe ratios-checkpoint.ipynb
# .\.ipynb_checkpoints\pe1-checkpoint.ipynb
# .\.ipynb_checkpoints\Stock Price Extraction API - Yahoo Based-checkpoint.ipynb
# 2
# ['current', 'tickers.txt']
# ('Ticker: ', 'current')
# ('Ticker: ', 'tickers.txt')

# %%
#!pip install quandl
# Out:
# Collecting quandl
#   Downloading Quandl-3.2.0-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.14 in c:\users\ashwini\anaconda2\lib\site-packages (from quandl)
# Collecting more-itertools (from quandl)
#   Downloading more_itertools-3.2.0-py2-none-any.whl
# Requirement already satisfied: numpy>=1.8 in c:\users\ashwini\anaconda2\lib\site-packages (from quandl)
# Requirement already satisfied: requests<2.18,>=2.7.0 in c:\users\ashwini\anaconda2\lib\site-packages (from quandl)
# Requirement already satisfied: six in c:\users\ashwini\anaconda2\lib\site-packages (from quandl)
# Requirement already satisfied: python-dateutil in c:\users\ashwini\anaconda2\lib\site-packages (from quandl)
# Collecting inflection>=0.3.1 (from quandl)
#   Downloading inflection-0.3.1.tar.gz
# Requirement already satisfied: pytz>=2011k in c:\users\ashwini\anaconda2\lib\site-packages (from pandas>=0.14->quandl)
# Building wheels for collected packages: inflection
#   Running setup.py bdist_wheel for inflection: started
#   Running setup.py bdist_wheel for inflection: finished with status 'done'
#   Stored in directory: C:\Users\Ashwini\AppData\Local\pip\Cache\wheels\41\fa\e9\2995f4ab121e9f30f342fa2d43f0b27f851a0cb9f0d98d3b45
# Successfully built inflection
# Installing collected packages: more-itertools, inflection, quandl
# Successfully installed inflection-0.3.1 more-itertools-3.2.0 quandl-3.2.0

# %%
import quandl
data = quandl.get("ZACKS/FR")
# Out:
# DatasetNotFoundTraceback (most recent call last)
# <ipython-input-19-e23146ec8a6d> in <module>()
#       1 import quandl
# ----> 2 data = quandl.get("ZACKS/FR")
#
# C:\Users\Ashwini\Anaconda2\lib\site-packages\quandl\Quandl.py in get(dataset, **kwargs)
#     131         elif str(e) == 'HTTP Error 404: Not Found':
#     132             error = "Dataset not found. Check Quandl code: {} for errors".format(dataset)
# --> 133             raise DatasetNotFound(error)
#     134
#     135         #Catch all
#
# DatasetNotFound: Dataset not found. Check Quandl code: ZACKS/FR for errors

# %%
data
# Out:
#               Value
# Date
# 1947-01-01    243.1
# 1947-04-01    246.3
# 1947-07-01    250.1
# 1947-10-01    260.3
# 1948-01-01    266.2
# 1948-04-01    272.9
# 1948-07-01    279.5
# 1948-10-01    280.7
# 1949-01-01    275.4
# 1949-04-01    271.7
# 1949-07-01    273.3
# 1949-10-01    271.0
# 1950-01-01    281.2
# 1950-04-01    290.7
# 1950-07-01    308.5
# 1950-10-01    320.3
# 1951-01-01    336.4
# 1951-04-01    344.5
# 1951-07-01    351.8
# 1951-10-01    356.6
# 1952-01-01    360.2
# 1952-04-01    361.4
# 1952-07-01    368.1
# 1952-10-01    381.2
# 1953-01-01    388.5
# 1953-04-01    392.3
# 1953-07-01    391.7
# 1953-10-01    386.5
# 1954-01-01    385.9
# 1954-04-01    386.7
# ...             ...
# 2010-01-01  14681.1
# 2010-04-01  14888.6
# 2010-07-01  15057.7
# 2010-10-01  15230.2
# 2011-01-01  15238.4
# 2011-04-01  15460.9
# 2011-07-01  15587.1
# 2011-10-01  15785.3
# 2012-01-01  15973.9
# 2012-04-01  16121.9
# 2012-07-01  16227.9
# 2012-10-01  16297.3
# 2013-01-01  16475.4
# 2013-04-01  16541.4
# 2013-07-01  16749.3
# 2013-10-01  16999.9
# 2014-01-01  17031.3
# 2014-04-01  17320.9
# 2014-07-01  17622.3
# 2014-10-01  17735.9
# 2015-01-01  17874.7
# 2015-04-01  18093.2
# 2015-07-01  18227.7
# 2015-10-01  18287.2
# 2016-01-01  18325.2
# 2016-04-01  18538.0
# 2016-07-01  18729.1
# 2016-10-01  18905.5
# 2017-01-01  19057.7
# 2017-04-01  19250.0
#
# [282 rows x 1 columns]

# %%
API_KEY="54n9LHU8TR3xyZksit83" 
url = "https://www.quandl.com/api/v3/datatables/ZACKS/FR.csv?ticker=AAPL&api_key="+API_KEY
#url = "https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?ticker="+ticker+"&api_key="+API_KEY
r = requests.get(url, stream=True)
virtual_file = ""
for chunk in r.iter_content(chunk_size=1024): 
    if chunk: # filter out keep-alive new chunks
        virtual_file += chunk + "\n"
    virtual_file += chunk
    result = virtual_file.replace('"', '').strip('\r\n')
    result = virtual_file
    with open(os.path.join("", ticker + "_EPS.txt"), "w") as writer:
        writer.write(result)
# Out:
# m
# ['m_ticker' 'ticker' 'comp_name' 'comp_name_2' 'exchange' 'currency_code'
#  'per_end_date' 'per_type' 'per_code' 'per_fisc_year' 'per_fisc_qtr'
#  'per_cal_year' 'per_cal_qtr' 'form_7_type' 'curr_ratio'
#  'non_perform_asset_tot_loan' 'loan_loss_reserve' 'lterm_debt_cap'
#  'tot_debt_tot_equity' 'gross_margin' 'oper_profit_margin' 'ebit_margin'
#  'ebitda_margin' 'pretax_profit_margin' 'profit_margin' 'free_cash_flow'
#  'loss_ratio' 'exp_ratio' 'comb_ratio' 'asset_turn' 'invty_turn' 'rcv_turn'
#  'day_sale_rcv' 'ret_equity' 'ret_tang_equity' 'ret_asset' 'ret_invst'
#  'free_cash_flow_per_share' 'book_val_per_share' 'oper_cash_flow_per_share']
#    m_ticker  ticker  comp_name  comp_name_2  exchange  currency_code  \
# 0      AAPL    AAPL  APPLE INC   Apple Inc.      NSDQ            USD
# 1      AAPL    AAPL  APPLE INC   Apple Inc.      NSDQ            USD
# 2      AAPL    AAPL  APPLE INC   Apple Inc.        NS            NaN
# 3  m_ticker  ticker  comp_name  comp_name_2  exchange  currency_code
# 4      AAPL    AAPL  APPLE INC   Apple Inc.      NSDQ            USD
#
#    per_end_date  per_type  per_code  per_fisc_year            ...             \
# 0    2011-09-30         A       NaN           2011            ...
# 1    2012-09-30         A       NaN           2012            ...
# 2           NaN       NaN       NaN            NaN            ...
# 3  per_end_date  per_type  per_code  per_fisc_year            ...
# 4    2011-09-30         A       NaN           2011            ...
#
#    invty_turn  rcv_turn  day_sale_rcv  ret_equity  ret_tang_equity  ret_asset  \
# 0     83.0296    9.2386        39.508     33.8341          35.9115    22.2753
# 1    111.0569     8.373       43.5925     35.3041          36.9806    23.7033
# 2         NaN       NaN           NaN         NaN              NaN        NaN
# 3  invty_turn  rcv_turn  day_sale_rcv  ret_equity  ret_tang_equity  ret_asset
# 4     83.0296    9.2386        39.508     33.8341          35.9115    22.2753
#
#    ret_invst  free_cash_flow_per_share  book_val_per_share  \
# 0    33.8341                    5.0742              11.778
# 1    35.3041                    6.4316             17.9802
# 2        NaN                       NaN                 NaN
# 3  ret_invst  free_cash_flow_per_share  book_val_per_share
# 4    33.8341                    5.0742              11.778
#
#    oper_cash_flow_per_share
# 0                    5.7239
# 1                    7.6851
# 2                       NaN
# 3  oper_cash_flow_per_share
# 4                    5.7239
#
# [5 rows x 40 columns]
# AttributeErrorTraceback (most recent call last)
# <ipython-input-36-eba9c23508cd> in <module>()
#      18 print res.columns.values
#      19 print res.head()
# ---> 20 res.calendardate = pd.to_datetime(res.calendardate, format="%Y-%m-%d", errors="coerce")
#      21 quart = res.set_index(['calendardate'])
#      22 monthly = quart.pe.resample("M", how="mean").dropna()
#
# C:\Users\Ashwini\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'calendardate'

# %%
#print result[0]
res = pd.read_csv(os.path.join("", ticker + "_EPS.txt"))
#print res.columns.values
#print res.head()
#res.calendardate = pd.to_datetime(res.calendardate, format="%Y-%m-%d", errors="coerce")
#quart = res.set_index(['calendardate'])
#monthly = quart.pe.resample("M", how="mean").dropna()

#print monthly.head()
#print monthly

# %%
res
# Out:
#     m_ticker   ticker   comp_name  comp_name_2  exchange  currency_code  \
# 0       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 1       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 2       AAPL     AAPL   APPLE INC   Apple Inc.        NS            NaN
# 3   m_ticker   ticker   comp_name  comp_name_2  exchange  currency_code
# 4       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 5       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 6       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 7       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 8       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 9       AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 10      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 11        DQ      USD  2013-09-30            A       NaN           2013
# 12      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 13      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 14      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 15      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 16      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 17      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 18      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 19      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 20      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 21        13  14154.0         NaN          NaN       NaN         0.2599
# 22      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 23      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 24      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 25      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 26      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 27      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 28      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 29      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# ..       ...      ...         ...          ...       ...            ...
# 42       NaN     NSDQ         USD   2013-09-30         Q            NaN
# 43      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 44      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 45      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 46      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 47      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 48      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 49      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 50      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 51      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 52        76  58.1561      7.5905       8.2373    3.6521         6.0249
# 53      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 54      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 55      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 56      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 57      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 58      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 59      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 60      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 61      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 62         4        7      1.0017          NaN       NaN         0.2932
# 63      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 64      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 65      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 66      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 67      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 68      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 69       028   8.6872      4.4523      25.1911    5.0781            NaN
# 70      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
# 71      AAPL     AAPL   APPLE INC   Apple Inc.      NSDQ            USD
#
#     per_end_date  per_type  per_code  per_fisc_year            ...             \
# 0     2011-09-30         A       NaN           2011            ...
# 1     2012-09-30         A       NaN           2012            ...
# 2            NaN       NaN       NaN            NaN            ...
# 3   per_end_date  per_type  per_code  per_fisc_year            ...
# 4     2011-09-30         A       NaN           2011            ...
# 5     2012-09-30         A       NaN           2012            ...
# 6     2013-09-30         A       NaN           2013            ...
# 7     2014-09-30         A       NaN           2014            ...
# 8     2015-09-30         A       NaN           2015            ...
# 9     2016-09-30         A       NaN           2016            ...
# 10    2011-03-31         Q       NaN           2011            ...
# 11             4      2013         3              7            ...
# 12    2014-09-30         A       NaN           2014            ...
# 13    2015-09-30         A       NaN           2015            ...
# 14    2016-09-30         A       NaN           2016            ...
# 15    2011-03-31         Q       NaN           2011            ...
# 16    2011-06-30         Q       NaN           2011            ...
# 17    2011-09-30         Q       NaN           2011            ...
# 18    2011-12-31         Q       NaN           2012            ...
# 19    2012-03-31         Q       NaN           2012            ...
# 20    2012-06-30         Q       NaN           2012            ...
# 21       15.5366    2.2233   40.4812         9.7386            ...
# 22    2011-06-30         Q       NaN           2011            ...
# 23    2011-09-30         Q       NaN           2011            ...
# 24    2011-12-31         Q       NaN           2012            ...
# 25    2012-03-31         Q       NaN           2012            ...
# 26    2012-06-30         Q       NaN           2012            ...
# 27    2012-09-30         Q       NaN           2012            ...
# 28    2012-12-31         Q       NaN           2013            ...
# 29    2013-03-31         Q       NaN           2013            ...
# ..           ...       ...       ...            ...            ...
# 42          2013         4      2013              3            ...
# 43    2013-12-31         Q       NaN           2014            ...
# 44    2014-03-31         Q       NaN           2014            ...
# 45    2014-06-30         Q       NaN           2014            ...
# 46    2014-09-30         Q       NaN           2014            ...
# 47    2014-12-31         Q       NaN           2015            ...
# 48    2015-03-31         Q       NaN           2015            ...
# 49    2015-06-30         Q       NaN           2015            ...
# 50    2015-09-30         Q       NaN           2015            ...
# 51    2015-12-31         Q       NaN           2016            ...
# 52        8.1896   19.0153    9.7528            NaN            ...
# 53    2014-12-31         Q       NaN           2015            ...
# 54    2015-03-31         Q       NaN           2015            ...
# 55    2015-06-30         Q       NaN           2015            ...
# 56    2015-09-30         Q       NaN           2015            ...
# 57    2015-12-31         Q       NaN           2016            ...
# 58    2016-03-31         Q       NaN           2016            ...
# 59    2016-06-30         Q       NaN           2016            ...
# 60    2016-09-30         Q       NaN           2016            ...
# 61    2016-12-31         Q       NaN           2017            ...
# 62        0.4909   40.0978   31.8576        31.8576            ...
# 63    2016-03-31         Q       NaN           2016            ...
# 64    2016-06-30         Q       NaN           2016            ...
# 65    2016-09-30         Q       NaN           2016            ...
# 66    2016-12-31         Q       NaN           2017            ...
# 67    2017-03-31         Q       NaN           2017            ...
# 68    2017-06-30         Q       NaN           2017            ...
# 69           NaN       NaN       NaN            NaN            ...
# 70    2017-03-31         Q       NaN           2017            ...
# 71    2017-06-30         Q       NaN           2017            ...
#
#     invty_turn  rcv_turn  day_sale_rcv  ret_equity  ret_tang_equity  \
# 0      83.0296    9.2386        39.508     33.8341          35.9115
# 1     111.0569     8.373       43.5925     35.3041          36.9806
# 2          NaN       NaN           NaN         NaN              NaN
# 3   invty_turn  rcv_turn  day_sale_rcv  ret_equity  ret_tang_equity
# 4      83.0296    9.2386        39.508     33.8341          35.9115
# 5     111.0569     8.373       43.5925     35.3041          36.9806
# 6      60.4342    8.2801       44.0815     29.9776          31.4425
# 7      53.1776    6.7157       54.3501     35.4201           38.438
# 8      59.6377    7.7024       47.3876     44.7355          48.3878
# 9       61.621    7.3599       49.5928     35.6237          38.1906
# 10         NaN       NaN           NaN         NaN              NaN
# 11     31.4425   17.8923       26.3592      6.9769          19.6281
# 12     53.1776    6.7157       54.3501     35.4201           38.438
# 13     59.6377    7.7024       47.3876     44.7355          48.3878
# 14      61.621    7.3599       49.5928     35.6237          38.1906
# 15     15.5366    2.2233       40.4812      9.7386           9.9404
# 16     18.7278    2.4907       36.1342     10.5389          10.8374
# 17     21.7655    2.4127       37.3021      8.6445           9.1753
# 18     20.7363    2.8108       32.0195     14.5069          15.2464
# 19     18.7133     2.846       31.6238     11.3388          11.8892
# 20         NaN       NaN           NaN         NaN              NaN
# 21         NaN       NaN           NaN         NaN              NaN
# 22     18.7278    2.4907       36.1342     10.5389          10.8374
# 23     21.7655    2.4127       37.3021      8.6445           9.1753
# 24     20.7363    2.8108       32.0195     14.5069          15.2464
# 25     18.7133     2.846       31.6238     11.3388          11.8892
# 26     17.8512    2.4495       36.7421      7.8965           8.3022
# 27      27.263    1.9241       46.7742      6.9563           7.2866
# 28     22.9911    2.5314       35.5529     10.2697          10.7635
# 29     21.8908    3.2696       27.5266      7.0463           7.3464
# ..         ...       ...           ...         ...              ...
# 42      6.0802    6.3773         3.629      5.3463           6.9769
# 43     16.8464    2.2857        39.376     10.0799          10.5797
# 44     15.1443    2.8853       31.1922      8.5065           8.9522
# 45      14.239    2.2227       40.4918      6.4065           6.7492
# 46     12.3704    1.5476       58.1561      7.5905           8.2373
# 47     19.6487    2.4886       36.1646     14.6147           15.765
# 48     14.3381    3.1937       28.1807     10.5181          11.2855
# 49     14.6543    2.4918       36.1179      8.4956            9.137
# 50     13.1771    1.6973       53.0256      9.3201           10.081
# 51         NaN       NaN           NaN         NaN              NaN
# 52         NaN       NaN           NaN         NaN              NaN
# 53     19.6487    2.4886       36.1646     14.6147           15.765
# 54     14.3381    3.1937       28.1807     10.5181          11.2855
# 55     14.6543    2.4918       36.1179      8.4956            9.137
# 56     13.1771    1.6973       53.0256      9.3201           10.081
# 57      18.543    3.0816       29.2056     14.3147          15.4112
# 58      13.431    2.5503       35.2901      8.0609           8.6648
# 59     14.3375    2.2245       40.4594      6.1608           6.6195
# 60     13.6205    1.5991       56.2817      7.0285            7.535
# 61     17.7636    2.8006       32.1365     13.5139          14.4144
# 62         NaN       NaN           NaN         NaN              NaN
# 63      13.431    2.5503       35.2901      8.0609           8.6648
# 64     14.3375    2.2245       40.4594      6.1608           6.6195
# 65     13.6205    1.5991       56.2817      7.0285            7.535
# 66     17.7636    2.8006       32.1365     13.5139          14.4144
# 67     11.1014    2.5663       35.0703      8.2256           8.7537
# 68      8.8748    2.0064       44.8573      6.5826           7.0117
# 69         NaN       NaN           NaN         NaN              NaN
# 70     11.1014    2.5663       35.0703      8.2256           8.7537
# 71      8.8748    2.0064       44.8573      6.5826           7.0117
#
#     ret_asset  ret_invst  free_cash_flow_per_share  book_val_per_share  \
# 0     22.2753    33.8341                    5.0742              11.778
# 1     23.7033    35.3041                    6.4316             17.9802
# 2         NaN        NaN                       NaN                 NaN
# 3   ret_asset  ret_invst  free_cash_flow_per_share  book_val_per_share
# 4     22.2753    33.8341                    5.0742              11.778
# 5     23.7033    35.3041                    6.4316             17.9802
# 6     17.8923    26.3592                    6.9769             19.6281
# 7      17.042    28.1142                    8.1896             19.0153
# 8     18.3899    30.9201                   12.0867             21.3946
# 9     14.2024    22.4312                    9.6522             24.0339
# 10        NaN        NaN                       NaN                 NaN
# 11     8.2289        NaN                       NaN                 NaN
# 12     17.042    28.1142                    8.1896             19.0153
# 13    18.3899    30.9201                   12.0867             21.3946
# 14    14.2024    22.4312                    9.6522             24.0339
# 15     6.3085     9.7386                    2.1604              9.4979
# 16     6.8454    10.5389                    3.7298             10.6873
# 17     5.6913     8.6445                    5.0742              11.778
# 18     9.4202    14.5069                    2.4629             13.8003
# 19     7.7001    11.3388                    4.3471             15.6608
# 20        NaN        NaN                       NaN                 NaN
# 21        NaN        NaN                       NaN                 NaN
# 22     6.8454    10.5389                    3.7298             10.6873
# 23     5.6913     8.6445                    5.0742              11.778
# 24     9.4202    14.5069                    2.4629             13.8003
# 25     7.7001    11.3388                    4.3471             15.6608
# 26      5.417     7.8965                     5.564             17.0322
# 27     4.6705     6.9563                    6.4316             17.9802
# 28     6.6695    10.2697                    3.1836             19.3747
# 29     4.9024     7.0463                    4.7726             20.5891
# ..        ...        ...                       ...                 ...
# 42    19.6281     8.2289                       NaN                 NaN
# 43      5.805      8.914                     3.278              20.759
# 44     4.9629     7.4544                    5.3342             19.9229
# 45     3.4819     5.1664                    6.7283             20.1931
# 46     3.6521     6.0249                    8.1896             19.0153
# 47     6.8822    11.5663                    5.1863              21.167
# 48      5.195     8.0253                    8.0922              22.388
# 49     3.9088     6.1683                   10.4211             22.0277
# 50     3.8313     6.4418                   12.0867             21.3946
# 51        NaN        NaN                       NaN                 NaN
# 52        NaN        NaN                       NaN                 NaN
# 53     6.8822    11.5663                    5.1863              21.167
# 54      5.195     8.0253                    8.0922              22.388
# 55     3.9088     6.1683                   10.4211             22.0277
# 56     3.8313     6.4418                   12.0867             21.3946
# 57     6.2605    10.1179                    4.2636             23.1342
# 58     3.4447     5.2624                    5.9767             23.8128
# 59      2.551     3.9881                    7.4808             23.4639
# 60     2.8021     4.4257                    9.6522             24.0339
# 61        5.4        NaN                       NaN                 NaN
# 62        NaN        NaN                       NaN                 NaN
# 63     3.4447     5.2624                    5.9767             23.8128
# 64      2.551     3.9881                    7.4808             23.4639
# 65     2.8021     4.4257                    9.6522             24.0339
# 66     5.4028     8.6872                    4.4523             25.1911
# 67     3.2968      5.045                    6.3231             25.7562
# 68     2.5254     3.9215                      7.52             25.6152
# 69        NaN        NaN                       NaN                 NaN
# 70     3.2968      5.045                    6.3231             25.7562
# 71     2.5254     3.9215                      7.52             25.6152
#
#     oper_cash_flow_per_share
# 0                     5.7239
# 1                     7.6851
# 2                        NaN
# 3   oper_cash_flow_per_share
# 4                     5.7239
# 5                     7.6851
# 6                     8.2289
# 7                     9.7528
# 8                    14.0281
# 9                    11.9674
# 10                       NaN
# 11                       NaN
# 12                    9.7528
# 13                   14.0281
# 14                   11.9674
# 15                    2.4409
# 16                    4.1282
# 17                    5.7239
# 18                    2.6633
# 19                    4.7671
# 20                       NaN
# 21                       NaN
# 22                    4.1282
# 23                    5.7239
# 24                    2.6633
# 25                    4.7671
# 26                    6.2932
# 27                    7.6851
# 28                    3.5331
# 29                    5.4257
# ..                       ...
# 42                       NaN
# 43                    3.5926
# 44                    5.8811
# 45                    7.6777
# 46                    9.7528
# 47                    5.7333
# 48                    9.0496
# 49                   11.7426
# 50                   14.0281
# 51                       NaN
# 52                       NaN
# 53                    5.7333
# 54                    9.0496
# 55                   11.7426
# 56                   14.0281
# 57                    4.9093
# 58                    7.0501
# 59                    9.0809
# 60                   11.9674
# 61                       NaN
# 62                       NaN
# 63                    7.0501
# 64                    9.0809
# 65                   11.9674
# 66                    5.0781
# 67                    7.5221
# 68                    9.1606
# 69                       NaN
# 70                    7.5221
# 71                    9.1606
#
# [72 rows x 40 columns]
