# %%
import tweepy
#from tweepy import Stream
#from tweepy import OAuthHandler
#from tweepy.streaming import StreamListerner
import csv

#Twitter API credentials
consumer_key = "1xnMYOD5FkrwVKakAAaAaqOyD"
consumer_secret = "hf1ADLyEPWll1rl43sGHdwl7eMWmK1LbzU6ajSxQKbwB86I15D"
access_key = "732181352326434816-XpBDVRPACxdBtChDFqxVhH2bz5nRGm0"
access_secret = "2tu6wcnVBTy6aZNtNjYrSmzzJv1pAvGI2YbTNgjXPc8rv"

NoOfTweets=100 # May be assuming 5 per day; would get 6 months data


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=NoOfTweets)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print ("getting tweets before %s" % (oldest))
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=NoOfTweets,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print ("...%s tweets downloaded so far" % (len(alltweets)))

    #transform the tweepy tweets into a 2D array that will populate the csv	
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    
    #write the csv	
    with open('%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)
    
    pass
    return outtweets

if __name__ == '__main__':
    #pass in the username of the account you want to download
    outtweets = get_all_tweets("BloombergTV")

#outtweets.filter(track=["car"])
print (outtweets)
# Out:
# getting tweets before 923234579506348031
# ...200 tweets downloaded so far
# getting tweets before 922975793915056128
# ...300 tweets downloaded so far
# getting tweets before 922765129111953407
# ...400 tweets downloaded so far
# getting tweets before 922486226392723455
# ...500 tweets downloaded so far
# getting tweets before 921407938115395584
# ...600 tweets downloaded so far
# getting tweets before 921069021075685375
# ...700 tweets downloaded so far
# getting tweets before 920385922511900673
# ...800 tweets downloaded so far
# getting tweets before 919930044624994303
# ...900 tweets downloaded so far
# getting tweets before 918653730509045764
# ...1000 tweets downloaded so far
# getting tweets before 918193922332962815
# ...1100 tweets downloaded so far
# getting tweets before 917827639527772159
# ...1200 tweets downloaded so far
# getting tweets before 916727294189850624
# ...1300 tweets downloaded so far
# getting tweets before 916048621115756545
# ...1400 tweets downloaded so far
# getting tweets before 915615961276968959
# ...1500 tweets downloaded so far
# getting tweets before 915284864546488319
# ...1600 tweets downloaded so far
# getting tweets before 914867260967157759
# ...1700 tweets downloaded so far
# getting tweets before 913876313588379647
# ...1800 tweets downloaded so far
# getting tweets before 913527746914955264
# ...1900 tweets downloaded so far
# getting tweets before 913173910648164351
# ...2000 tweets downloaded so far
# getting tweets before 912827901329977343
# ...2100 tweets downloaded so far
# getting tweets before 912434350985240577
# ...2200 tweets downloaded so far
# getting tweets before 911664672872558597
# ...2300 tweets downloaded so far
# getting tweets before 911082528232038406
# ...2400 tweets downloaded so far
# getting tweets before 910829046941937663
# ...2500 tweets downloaded so far
# getting tweets before 910484968752713727
# ...2600 tweets downloaded so far
# getting tweets before 910145389113745407
# ...2700 tweets downloaded so far
# getting tweets before 909676491251658751
# ...2800 tweets downloaded so far
# getting tweets before 908528310019379199
# ...2900 tweets downloaded so far
# getting tweets before 908167209138212863
# ...3000 tweets downloaded so far
# getting tweets before 907937332480835585
# ...3100 tweets downloaded so far
# getting tweets before 907535399458930687
# ...3200 tweets downloaded so far
# getting tweets before 906604520783855615
# ...3211 tweets downloaded so far
# getting tweets before 906549137088413695
# ...3211 tweets downloaded so far
# [['923390257290186753', datetime.datetime(2017, 10, 26, 3, 26, 7), b"Even Illinois's CFO doesn't know how many bills are unpaid https://t.co/vwemitbbEc https://t.co/hWSL4j7GyA"], ['923388474711003136', datetime.datetime(2017, 10, 26, 3, 19, 2), b'The Senate Judiciary Committee\xe2\x80\x99s bipartisan Russia probe has fractured https://t.co/2KLqmic7IL https://t.co/6x28nVQkN5'], ['923388473050099712', datetime.datetime(2017, 10, 26, 3, 19, 2), b"Osaka's love of super-cheap sales may be undercutting the central bank https://t.co/ydfHHmwRy5 https://t.co/1HAhFAC5X4"], ['923383447250456576', datetime.datetime(2017, 10, 26, 2, 59, 4), b'Memorize these faces - these men be running China for the next 5 years https://t.co/pYhRcbuVmz https://t.co/xPqkiMpaTZ'], ['923382713343758337', datetime.datetime(2017, 10, 26, 2, 56, 9), b'Why foodies should flock to San Francisco instead of New York https://t.co/ZSg41dpvsi https://t.co/OQMsPgAeJr'], ['923380930114400256', datetime.datetime(2017, 10, 26, 2, 49, 3), b'What you need to know about the 7 men who will rule China for the next 5 years https://t.co/sKF5yqhlAN https://t.co/vMS7oKxt2k'], ['923373894651793408', datetime.datetime(2017, 10, 26, 2, 21, 6), b'Ford faces fire from green groups in showdown over mileage rules  https://t.co/PMO8DA5Ngv https://t.co/upfNrPgVxJ'], ['923372887859449857', datetime.datetime(2017, 10, 26, 2, 17, 6), b'Texas becomes "